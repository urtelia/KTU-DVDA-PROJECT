# %% [markdown]
# Link to supporting video for below notebook walkhthrough - https://www.youtube.com/watch?v=91QljBnvM7s

# %%
#this command might be relevant ony on GPU nodes. But the notebook will run on CPU as well
#If running on CPU remove the command wherever it appears
# !nvidia-smi
# Out:
# Wed Oct 19 18:09:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W /  70W |    190MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !apt-get install default-jre
# !java -version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# default-jre is already the newest version (2:1.11-68ubuntu1~18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# openjdk version "11.0.16" 2022-07-19
# OpenJDK Runtime Environment (build 11.0.16+8-post-Ubuntu-0ubuntu118.04)
# OpenJDK 64-Bit Server VM (build 11.0.16+8-post-Ubuntu-0ubuntu118.04, mixed mode, sharing)

# %%
# !pip install h2o
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: h2o in /usr/local/lib/python3.7/dist-packages (3.38.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from h2o) (0.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o) (0.8.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (3.0.4)

# %%
 import h2o

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         23 mins 11 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.1
# H2O_cluster_version_age:    1 month
# H2O_cluster_name:           H2O_from_python_unknownUser_vn6euz
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    2.827 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.15 final
# --------------------------  ----------------------------------

# %%
from h2o.automl import H2OAutoML

# %%
df = h2o.import_file('https://drive.google.com/u/0/uc?id=14XVqtU6y7hs9LvrX5dyPSp5KCBix2PuX&export=download')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
df.types
# Out:
# {'id': 'int',
#  'y': 'int',
#  'amount_current_loan': 'int',
#  'term': 'enum',
#  'credit_score': 'enum',
#  'loan_purpose': 'enum',
#  'yearly_income': 'int',
#  'home_ownership': 'enum',
#  'bankruptcies': 'int'}

# %%
df.describe()
# Out:
# Rows:1000000
# Cols:9
#          id                 y                   amount_current_loan    term    credit_score    loan_purpose        yearly_income       home_ownership    bankruptcies
# -------  -----------------  ------------------  ---------------------  ------  --------------  ------------------  ------------------  ----------------  -------------------
# type     int                int                 int                    enum    enum            enum                int                 enum              int
# mins     1.0                0.0                 10802.0                                                            76627.0                               0.0
# mean     500000.5           0.5                 316659.3714679997                                                  1344805.2238531003                    0.11921117617299239
# maxs     1000000.0          1.0                 789250.0                                                           165557393.0                           7.0
# sigma    288675.2789323441  0.5000002500001874  186863.51428798572                                                 1278949.921243987                     0.3546738360737797
# zeros    0                  500000              0                                                                  0                                     886855
# missing  0                  0                   0                      0       0               0                   219439              0                 1805
# 0        1.0                0.0                 386342.0               short   very_good       other               1371971.0           rent              0.0
# 1        2.0                0.0                 429000.0               short   good            debt_consolidation  823042.0            mortgage          0.0
# 2        3.0                0.0                 344608.0               short   good            debt_consolidation  1316567.0           rent              0.0
# 3        4.0                0.0                 71214.0                short   NA              debt_consolidation  nan                 rent              0.0
# 4        5.0                0.0                 654126.0               short   good            debt_consolidation  1242847.0           rent              0.0
# 5        6.0                0.0                 133034.0               short   good            debt_consolidation  651035.0            rent              0.0
# 6        7.0                0.0                 317570.0               short   good            debt_consolidation  1937601.0           mortgage          0.0
# 7        8.0                0.0                 227986.0               long    good            debt_consolidation  469680.0            rent              1.0
# 8        9.0                0.0                 409354.0               short   good            other               815480.0            rent              0.0
# 9        10.0               0.0                 206448.0               short   good            debt_consolidation  1359792.0           own               0.0
# [1000000 rows x 9 columns]

# %%
train,test,valid = df.split_frame(ratios=[.7, .15])

# %%
train
# Out:
#   id    y    amount_current_loan  term    credit_score    loan_purpose           yearly_income  home_ownership      bankruptcies
# ----  ---  ---------------------  ------  --------------  ------------------  ----------------  ----------------  --------------
#    3    0                 344608  short   good            debt_consolidation       1.31657e+06  rent                           0
#    4    0                  71214  short   NA              debt_consolidation     nan            rent                           0
#    5    0                 654126  short   good            debt_consolidation       1.24285e+06  rent                           0
#    6    0                 133034  short   good            debt_consolidation  651035            rent                           0
#    7    0                 317570  short   good            debt_consolidation       1.9376e+06   mortgage                       0
#    8    0                 227986  long    good            debt_consolidation  469680            rent                           1
#    9    0                 409354  short   good            other               815480            rent                           0
#   10    0                 206448  short   good            debt_consolidation       1.35979e+06  own                            0
#   11    0                 440880  short   good            debt_consolidation       1.72624e+06  rent                           0
#   12    0                 220000  short   good            debt_consolidation  722000            rent                           0
# [699987 rows x 9 columns]

# %%
y = "y"
x = df.columns
x.remove(y)
x.remove("id")

# %%
aml = H2OAutoML(max_models = 10, seed = 10, exclude_algos = ["StackedEnsemble", "DeepLearning"], verbosity="info", nfolds=0)

# %%
# !nvidia-smi
# Out:
# Wed Oct 19 18:10:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W /  70W |    190MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
aml.train(x = x, y = y, training_frame = train, validation_frame=valid)
# Out:
# AutoML progress: |
# 18:10:14.209: Project: AutoML_3_20221019_181014
# 18:10:14.209: Cross-validation disabled by user: no fold column nor nfolds > 1.
# 18:10:14.209: Setting stopping tolerance adaptively based on the training frame: 0.0011952397080403554
# 18:10:14.209: Build control seed: 10
# 18:10:14.209: training frame: Frame key: AutoML_3_20221019_181014_training_py_18_sid_b7ee    cols: 9    rows: 699987  chunks: 15    size: 10932686  checksum: -407022757657175943
# 18:10:14.209: validation frame: Frame key: py_20_sid_b7ee    cols: 9    rows: 150077  chunks: 15    size: 2372043  checksum: -47570627059813899
# 18:10:14.210: leaderboard frame: Frame key: py_20_sid_b7ee    cols: 9    rows: 150077  chunks: 15    size: 2372043  checksum: -47570627059813899
# 18:10:14.210: blending frame: NULL
# 18:10:14.210: response column: y
# 18:10:14.210: fold column: null
# 18:10:14.210: weights column: null
# 18:10:14.210: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 18:10:14.211: Disabling Algo: DeepLearning as requested by the user.
# 18:10:14.212: Disabling Algo: StackedEnsemble as requested by the user.
# 18:10:14.212: AutoML job created: 2022.10.19 18:10:14.208
# 18:10:14.218: AutoML build started: 2022.10.19 18:10:14.218
# 18:10:14.220: AutoML: starting XGBoost_1_AutoML_3_20221019_181014 model training
# 18:10:14.220: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 18:10:42.602: New leader: XGBoost_1_AutoML_3_20221019_181014, rmse: 0.46130111377721017
# 18:10:42.603: AutoML: starting GLM_1_AutoML_3_20221019_181014 model training
# 18:10:42.604: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 18:10:45.697: AutoML: starting GBM_1_AutoML_3_20221019_181014 model training
# 18:10:45.697: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ████████
# 18:11:25.138: New leader: GBM_1_AutoML_3_20221019_181014, rmse: 0.4573387553073252
# 18:11:25.139: AutoML: starting XGBoost_2_AutoML_3_20221019_181014 model training
# 18:11:25.140: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 18:11:40.332: AutoML: starting DRF_1_AutoML_3_20221019_181014 model training
# 18:11:40.333: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 18:12:41.415: AutoML: starting GBM_2_AutoML_3_20221019_181014 model training
# 18:12:41.416: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 18:13:08.431: AutoML: starting GBM_3_AutoML_3_20221019_181014 model training
# 18:13:08.431: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 18:13:34.43: AutoML: starting GBM_4_AutoML_3_20221019_181014 model training
# 18:13:34.43: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ████
# 18:14:04.624: AutoML: starting XGBoost_3_AutoML_3_20221019_181014 model training
# 18:14:04.624: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 18:14:13.962: AutoML: starting XRT_1_AutoML_3_20221019_181014 model training
# 18:14:13.963: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █████████████████████████████████████| (done) 100%
#
# 18:15:25.915: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option or it is already trained.
# 18:15:25.916: Skipping StackedEnsemble 'best_of_family_xglm' due to the exclude_algos option or it is already trained.
# 18:15:25.916: Skipping StackedEnsemble 'all_xglm' due to the exclude_algos option or it is already trained.
# 18:15:25.916: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}]
# 18:15:25.916: AutoML build stopped: 2022.10.19 18:15:25.916
# 18:15:25.916: AutoML build done: built 10 models
# 18:15:25.916: AutoML duration:  5 min 11.698 sec
# Model Details
# =============
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_1_AutoML_3_20221019_181014
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     60                 60                          997639                 9            15           14.3333       1             2835          1320.22
#
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 0.2013764580353886
# RMSE: 0.4487498836048747
# MAE: 0.4129808763049413
# RMSLE: 0.3157552372813049
# Mean Residual Deviance: 0.2013764580353886
#
# ModelMetricsRegression: gbm
# ** Reported on validation data. **
#
# MSE: 0.20915873710605348
# RMSE: 0.4573387553073252
# MAE: 0.42117336402105043
# RMSLE: 0.32176208081070856
# Mean Residual Deviance: 0.20915873710605348
#
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_mae    training_deviance    validation_rmse    validation_mae    validation_deviance
# --  -------------------  ----------  -----------------  ---------------  --------------  -------------------  -----------------  ----------------  ---------------------
#     2022-10-19 18:10:45  0.003 sec   0                  0.5              0.5             0.25                 0.500001           0.5               0.250001
#     2022-10-19 18:10:48  3.145 sec   5                  0.475429         0.470833        0.226033             0.476633           0.472014          0.227179
#     2022-10-19 18:10:52  6.504 sec   10                 0.464428         0.452069        0.215694             0.46675            0.454328          0.217856
#     2022-10-19 18:10:55  9.988 sec   15                 0.459377         0.441635        0.211027             0.462784           0.444938          0.214169
#     2022-10-19 18:10:59  13.398 sec  20                 0.455944         0.433014        0.207885             0.460221           0.437154          0.211804
#     2022-10-19 18:11:02  16.807 sec  25                 0.453733         0.426533        0.205874             0.458905           0.431525          0.210594
#     2022-10-19 18:11:06  20.327 sec  30                 0.452001         0.42276         0.204304             0.458219           0.428732          0.209964
#     2022-10-19 18:11:09  23.718 sec  35                 0.450795         0.419339        0.203216             0.457786           0.426044          0.209568
#     2022-10-19 18:11:12  27.120 sec  40                 0.450017         0.416858        0.202516             0.457545           0.424071          0.209347
#     2022-10-19 18:11:16  30.653 sec  45                 0.449535         0.41563         0.202082             0.457484           0.423229          0.209291
#     2022-10-19 18:11:20  34.438 sec  50                 0.449185         0.414138        0.201767             0.45736            0.42195           0.209179
#     2022-10-19 18:11:23  37.368 sec  55                 0.448829         0.413245        0.201447             0.457346           0.421374          0.209166
#     2022-10-19 18:11:24  39.260 sec  60                 0.44875          0.412981        0.201376             0.457339           0.421173          0.209159
#
# Variable Importances:
# variable             relative_importance    scaled_importance    percentage
# -------------------  ---------------------  -------------------  ------------
# credit_score         68068                  1                    0.425181
# yearly_income        52055.1                0.764752             0.325158
# amount_current_loan  22772.5                0.334555             0.142246
# term                 8327.6                 0.122342             0.0520176
# loan_purpose         4317.86                0.0634346            0.0269712
# home_ownership       4080.11                0.0599417            0.0254861
# bankruptcies         470.689                0.00691498           0.00294012
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
# !nvidia-smi
# Out:
# Wed Oct 19 18:15:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    27W /  70W |    190MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
lb = aml.leaderboard

# %%
lb.head()
# Out:
# model_id                                rmse       mse       mae       rmsle    mean_residual_deviance
# ----------------------------------  --------  --------  --------  ----------  ------------------------
# GBM_1_AutoML_3_20221019_181014      0.457339  0.209159  0.421173    0.321762                  0.209159
# GBM_4_AutoML_3_20221019_181014      0.457918  0.209689  0.423177    0.322205                  0.209689
# XGBoost_2_AutoML_3_20221019_181014  0.45829   0.210029  0.420273    0.322188                  0.210029
# GBM_3_AutoML_3_20221019_181014      0.458291  0.210031  0.423793    0.32245                   0.210031
# DRF_1_AutoML_3_20221019_181014      0.458612  0.210325  0.42231     0.322731                  0.210325
# GBM_2_AutoML_3_20221019_181014      0.458762  0.210462  0.424836    0.32281                   0.210462
# XGBoost_3_AutoML_3_20221019_181014  0.459308  0.210964  0.424348    0.323017                  0.210964
# XRT_1_AutoML_3_20221019_181014      0.459383  0.211032  0.431501    0.323498                  0.211032
# XGBoost_1_AutoML_3_20221019_181014  0.461301  0.212799  0.418395    0.324106                  0.212799
# GLM_1_AutoML_3_20221019_181014      0.48007   0.230468  0.461232  nan                         0.230468
# [10 rows x 6 columns]

# %%
pred=aml.leader.predict(test)
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
pred.head()
# Out:
#   predict
# ---------
#  0.458803
#  0.572485
#  0.390219
#  0.777751
#  0.27774
#  0.700424
#  0.707605
#  0.5519
#  0.322255
#  0.357703
# [10 rows x 1 column]

# %%
aml.leader.model_performance(test)
# Out:
# ModelMetricsRegression: gbm
# ** Reported on test data. **
#
# MSE: 0.20934789599924553
# RMSE: 0.4575455124894632
# MAE: 0.42098401978077116
# RMSLE: 0.32189000941431095
# Mean Residual Deviance: 0.20934789599924553

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
#se = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_AllModels" in mid][0])
#metalearner = h2o.get_model(se.metalearner()['name'])

# %%
model_ids
# Out:
# ['GBM_1_AutoML_3_20221019_181014',
#  'GBM_4_AutoML_3_20221019_181014',
#  'XGBoost_2_AutoML_3_20221019_181014',
#  'GBM_3_AutoML_3_20221019_181014',
#  'DRF_1_AutoML_3_20221019_181014',
#  'GBM_2_AutoML_3_20221019_181014',
#  'XGBoost_3_AutoML_3_20221019_181014',
#  'XRT_1_AutoML_3_20221019_181014',
#  'XGBoost_1_AutoML_3_20221019_181014',
#  'GLM_1_AutoML_3_20221019_181014']

# %%
h2o.get_model([mid for mid in model_ids if "XGBoost" in mid][0])
# Out:
# Model Details
# =============
# H2OXGBoostEstimator : XGBoost
# Model Key: XGBoost_2_AutoML_3_20221019_181014
#
#
# Model Summary:
#     number_of_trees
# --  -----------------
#     35
#
# ModelMetricsRegression: xgboost
# ** Reported on train data. **
#
# MSE: 0.20454724841379648
# RMSE: 0.45226900005836845
# MAE: 0.4144979508197718
# RMSLE: 0.3180205600453932
# Mean Residual Deviance: 0.20454724841379648
#
# ModelMetricsRegression: xgboost
# ** Reported on validation data. **
#
# MSE: 0.21002935264457884
# RMSE: 0.45828959473740927
# MAE: 0.42027342183083777
# RMSLE: 0.32218834853599687
# Mean Residual Deviance: 0.21002935264457884
#
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_mae    training_deviance    validation_rmse    validation_mae    validation_deviance
# --  -------------------  ----------  -----------------  ---------------  --------------  -------------------  -----------------  ----------------  ---------------------
#     2022-10-19 18:11:25  0.001 sec   0                  0.5              0.5             0.25                 0.5                0.5               0.25
#     2022-10-19 18:11:25  0.818 sec   5                  0.458229         0.432856        0.209974             0.459608           0.434245          0.211239
#     2022-10-19 18:11:26  1.402 sec   10                 0.455801         0.421072        0.207754             0.458163           0.4234            0.209914
#     2022-10-19 18:11:27  2.417 sec   15                 0.455085         0.418113        0.207102             0.458063           0.421016          0.209822
#     2022-10-19 18:11:28  3.651 sec   20                 0.454098         0.416812        0.206205             0.458109           0.420692          0.209864
#     2022-10-19 18:11:30  5.223 sec   25                 0.453469         0.416102        0.205634             0.458202           0.420663          0.209949
#     2022-10-19 18:11:32  7.142 sec   30                 0.452713         0.415108        0.204949             0.458231           0.420403          0.209976
#     2022-10-19 18:11:35  10.064 sec  35                 0.452269         0.414498        0.204547             0.45829            0.420273          0.210029
#
# Variable Importances:
# variable                           relative_importance    scaled_importance      percentage
# ---------------------------------  ---------------------  ---------------------  ----------------------
# yearly_income                      16387.75390625         1.0                    0.39664511083258025
# amount_current_loan                4636.99755859375       0.28295503978890485    0.11223273311770732
# credit_score.good                  4488.0908203125        0.2738685756442084     0.10862863153995793
# credit_score.NA                    4278.8994140625        0.26110347022178576    0.10356541488489152
# credit_score.very_good             3107.821044921875      0.18964289204615203    0.07522092593425703
# credit_score.fair                  2239.457763671875      0.13665434424285475    0.05420327751796069
# term.short                         1586.3604736328125     0.09680158017431557    0.0383958734970103
# term.long                          961.6155395507812      0.058678910182074315   0.023274702832703886
# home_ownership.mortgage            577.8525390625         0.03526124094663865    0.013986198823373803
# home_ownership.rent                547.1145629882812      0.0333855735275364     0.013242224512038932
# ---                                ---                    ---                    ---
# loan_purpose.small_business        142.9476776123047      0.008722835260406674   0.0034598699586383436
# loan_purpose.buy_a_car             127.32109832763672     0.00776928303024362    0.0030816481286206655
# loan_purpose.major_purchase        115.3546142578125      0.0070390741109322055  0.002792014330889451
# loan_purpose.buy_house             83.07621002197266      0.005069407955307949   0.002010755880288685
# loan_purpose.take_a_trip           74.492431640625        0.004545615711999123   0.0018029962478882102
# loan_purpose.moving                52.18974685668945      0.003184679679427283   0.0012631876244127006
# loan_purpose.vacation              42.71484375            0.0026065099582505513  0.001033859431276514
# loan_purpose.educational_expenses  42.03619384765625      0.0025650979437532554  0.0010174335581964336
# loan_purpose.wedding               30.814329147338867     0.0018803265733436981  0.0007458223420853569
# loan_purpose.renewable_energy      6.0398030281066895     0.0003685558779231616  0.00014618588704683134
# [27 rows x 4 columns]
#
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
out = h2o.get_model([mid for mid in model_ids if "XGBoost" in mid][0])

# %%
out.params
# Out:
# {'model_id': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'ModelKeyV3',
#     'schema_type': 'Key<Model>'},
#    'name': 'XGBoost_2_AutoML_3_20221019_181014',
#    'type': 'Key<Model>',
#    'URL': '/3/Models/XGBoost_2_AutoML_3_20221019_181014'},
#   'input': None},
#  'training_frame': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>'},
#    'name': 'AutoML_3_20221019_181014_training_py_18_sid_b7ee',
#    'type': 'Key<Frame>',
#    'URL': '/3/Frames/AutoML_3_20221019_181014_training_py_18_sid_b7ee'},
#   'input': {'__meta': {'schema_version': 3,
#     'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>'},
#    'name': 'AutoML_3_20221019_181014_training_py_18_sid_b7ee',
#    'type': 'Key<Frame>',
#    'URL': '/3/Frames/AutoML_3_20221019_181014_training_py_18_sid_b7ee'}},
#  'validation_frame': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>'},
#    'name': 'py_20_sid_b7ee',
#    'type': 'Key<Frame>',
#    'URL': '/3/Frames/py_20_sid_b7ee'},
#   'input': {'__meta': {'schema_version': 3,
#     'schema_name': 'FrameKeyV3',
#     'schema_type': 'Key<Frame>'},
#    'name': 'py_20_sid_b7ee',
#    'type': 'Key<Frame>',
#    'URL': '/3/Frames/py_20_sid_b7ee'}},
#  'nfolds': {'default': 0, 'actual': 0, 'input': 0},
#  'keep_cross_validation_models': {'default': True,
#   'actual': False,
#   'input': False},
#  'keep_cross_validation_predictions': {'default': False,
#   'actual': True,
#   'input': True},
#  'keep_cross_validation_fold_assignment': {'default': False,
#   'actual': False,
#   'input': False},
#  'score_each_iteration': {'default': False, 'actual': False, 'input': False},
#  'fold_assignment': {'default': 'AUTO', 'actual': None, 'input': 'AUTO'},
#  'fold_column': {'default': None, 'actual': None, 'input': None},
#  'response_column': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier'},
#    'column_name': 'y',
#    'is_member_of_frames': None},
#   'input': {'__meta': {'schema_version': 3,
#     'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier'},
#    'column_name': 'y',
#    'is_member_of_frames': None}},
#  'ignored_columns': {'default': None, 'actual': ['id'], 'input': ['id']},
#  'ignore_const_cols': {'default': True, 'actual': True, 'input': True},
#  'offset_column': {'default': None, 'actual': None, 'input': None},
#  'weights_column': {'default': None, 'actual': None, 'input': None},
#  'stopping_rounds': {'default': 0, 'actual': 3, 'input': 3},
#  'stopping_metric': {'default': 'AUTO',
#   'actual': 'deviance',
#   'input': 'deviance'},
#  'stopping_tolerance': {'default': 0.001,
#   'actual': 0.0011952397080403554,
#   'input': 0.0011952397080403554},
#  'max_runtime_secs': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'seed': {'default': -1, 'actual': 13, 'input': 13},
#  'distribution': {'default': 'AUTO',
#   'actual': 'gaussian',
#   'input': 'gaussian'},
#  'tweedie_power': {'default': 1.5, 'actual': 1.5, 'input': 1.5},
#  'categorical_encoding': {'default': 'AUTO',
#   'actual': 'OneHotInternal',
#   'input': 'AUTO'},
#  'quiet_mode': {'default': True, 'actual': True, 'input': True},
#  'checkpoint': {'default': None, 'actual': None, 'input': None},
#  'export_checkpoints_dir': {'default': None, 'actual': None, 'input': None},
#  'ntrees': {'default': 50, 'actual': 10000, 'input': 10000},
#  'max_depth': {'default': 6, 'actual': 10, 'input': 10},
#  'min_rows': {'default': 1.0, 'actual': 5.0, 'input': 5.0},
#  'min_child_weight': {'default': 1.0, 'actual': 5.0, 'input': 1.0},
#  'learn_rate': {'default': 0.3, 'actual': 0.3, 'input': 0.3},
#  'eta': {'default': 0.3, 'actual': 0.3, 'input': 0.3},
#  'sample_rate': {'default': 1.0, 'actual': 0.6, 'input': 0.6},
#  'subsample': {'default': 1.0, 'actual': 0.6, 'input': 1.0},
#  'col_sample_rate': {'default': 1.0, 'actual': 0.8, 'input': 0.8},
#  'colsample_bylevel': {'default': 1.0, 'actual': 0.8, 'input': 1.0},
#  'col_sample_rate_per_tree': {'default': 1.0, 'actual': 0.8, 'input': 0.8},
#  'colsample_bytree': {'default': 1.0, 'actual': 0.8, 'input': 1.0},
#  'colsample_bynode': {'default': 1.0, 'actual': 1.0, 'input': 1.0},
#  'max_abs_leafnode_pred': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'max_delta_step': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'monotone_constraints': {'default': None, 'actual': None, 'input': None},
#  'interaction_constraints': {'default': None, 'actual': None, 'input': None},
#  'score_tree_interval': {'default': 0, 'actual': 5, 'input': 5},
#  'min_split_improvement': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'gamma': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'nthread': {'default': -1, 'actual': -1, 'input': -1},
#  'save_matrix_directory': {'default': None, 'actual': None, 'input': None},
#  'build_tree_one_node': {'default': False, 'actual': False, 'input': False},
#  'calibrate_model': {'default': False, 'actual': False, 'input': False},
#  'calibration_frame': {'default': None, 'actual': None, 'input': None},
#  'calibration_method': {'default': 'AUTO',
#   'actual': 'PlattScaling',
#   'input': 'AUTO'},
#  'max_bins': {'default': 256, 'actual': 256, 'input': 256},
#  'max_leaves': {'default': 0, 'actual': 0, 'input': 0},
#  'sample_type': {'default': 'uniform',
#   'actual': 'uniform',
#   'input': 'uniform'},
#  'normalize_type': {'default': 'tree', 'actual': 'tree', 'input': 'tree'},
#  'rate_drop': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'one_drop': {'default': False, 'actual': False, 'input': False},
#  'skip_drop': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'tree_method': {'default': 'auto', 'actual': 'hist', 'input': 'auto'},
#  'grow_policy': {'default': 'depthwise',
#   'actual': 'depthwise',
#   'input': 'depthwise'},
#  'booster': {'default': 'gbtree', 'actual': 'gbtree', 'input': 'gbtree'},
#  'reg_lambda': {'default': 1.0, 'actual': 1.0, 'input': 1.0},
#  'reg_alpha': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'dmatrix_type': {'default': 'auto', 'actual': 'sparse', 'input': 'auto'},
#  'backend': {'default': 'auto', 'actual': 'gpu', 'input': 'auto'},
#  'gpu_id': {'default': None, 'actual': None, 'input': None},
#  'gainslift_bins': {'default': -1, 'actual': -1, 'input': -1},
#  'auc_type': {'default': 'AUTO', 'actual': 'AUTO', 'input': 'AUTO'},
#  'scale_pos_weight': {'default': 1.0, 'actual': 1.0, 'input': 1.0}}

# %%
out.convert_H2OXGBoostParams_2_XGBoostParams()
# Out:
# ({'silent': True,
#   'updater': 'grow_gpu_hist',
#   'eta': 0.3,
#   'objective': 'reg:squarederror',
#   'min_child_weight': 5.0,
#   'nthread': 2,
#   'seed': 13,
#   'max_bin': 256,
#   'max_depth': 10,
#   'colsample_bytree': 0.8,
#   'lambda': 1.0,
#   'gamma': 0.0,
#   'gpu_id': 0,
#   'alpha': 0.0,
#   'booster': 'gbtree',
#   'grow_policy': 'depthwise',
#   'nround': 10000,
#   'subsample': 0.6,
#   'max_delta_step': 0.0,
#   'colsample_bylevel': 0.8},
#  10000)

# %%
out
# Out:
# Model Details
# =============
# H2OXGBoostEstimator : XGBoost
# Model Key: XGBoost_2_AutoML_3_20221019_181014
#
#
# Model Summary:
#     number_of_trees
# --  -----------------
#     35
#
# ModelMetricsRegression: xgboost
# ** Reported on train data. **
#
# MSE: 0.20454724841379648
# RMSE: 0.45226900005836845
# MAE: 0.4144979508197718
# RMSLE: 0.3180205600453932
# Mean Residual Deviance: 0.20454724841379648
#
# ModelMetricsRegression: xgboost
# ** Reported on validation data. **
#
# MSE: 0.21002935264457884
# RMSE: 0.45828959473740927
# MAE: 0.42027342183083777
# RMSLE: 0.32218834853599687
# Mean Residual Deviance: 0.21002935264457884
#
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_mae    training_deviance    validation_rmse    validation_mae    validation_deviance
# --  -------------------  ----------  -----------------  ---------------  --------------  -------------------  -----------------  ----------------  ---------------------
#     2022-10-19 18:11:25  0.001 sec   0                  0.5              0.5             0.25                 0.5                0.5               0.25
#     2022-10-19 18:11:25  0.818 sec   5                  0.458229         0.432856        0.209974             0.459608           0.434245          0.211239
#     2022-10-19 18:11:26  1.402 sec   10                 0.455801         0.421072        0.207754             0.458163           0.4234            0.209914
#     2022-10-19 18:11:27  2.417 sec   15                 0.455085         0.418113        0.207102             0.458063           0.421016          0.209822
#     2022-10-19 18:11:28  3.651 sec   20                 0.454098         0.416812        0.206205             0.458109           0.420692          0.209864
#     2022-10-19 18:11:30  5.223 sec   25                 0.453469         0.416102        0.205634             0.458202           0.420663          0.209949
#     2022-10-19 18:11:32  7.142 sec   30                 0.452713         0.415108        0.204949             0.458231           0.420403          0.209976
#     2022-10-19 18:11:35  10.064 sec  35                 0.452269         0.414498        0.204547             0.45829            0.420273          0.210029
#
# Variable Importances:
# variable                           relative_importance    scaled_importance      percentage
# ---------------------------------  ---------------------  ---------------------  ----------------------
# yearly_income                      16387.75390625         1.0                    0.39664511083258025
# amount_current_loan                4636.99755859375       0.28295503978890485    0.11223273311770732
# credit_score.good                  4488.0908203125        0.2738685756442084     0.10862863153995793
# credit_score.NA                    4278.8994140625        0.26110347022178576    0.10356541488489152
# credit_score.very_good             3107.821044921875      0.18964289204615203    0.07522092593425703
# credit_score.fair                  2239.457763671875      0.13665434424285475    0.05420327751796069
# term.short                         1586.3604736328125     0.09680158017431557    0.0383958734970103
# term.long                          961.6155395507812      0.058678910182074315   0.023274702832703886
# home_ownership.mortgage            577.8525390625         0.03526124094663865    0.013986198823373803
# home_ownership.rent                547.1145629882812      0.0333855735275364     0.013242224512038932
# ---                                ---                    ---                    ---
# loan_purpose.small_business        142.9476776123047      0.008722835260406674   0.0034598699586383436
# loan_purpose.buy_a_car             127.32109832763672     0.00776928303024362    0.0030816481286206655
# loan_purpose.major_purchase        115.3546142578125      0.0070390741109322055  0.002792014330889451
# loan_purpose.buy_house             83.07621002197266      0.005069407955307949   0.002010755880288685
# loan_purpose.take_a_trip           74.492431640625        0.004545615711999123   0.0018029962478882102
# loan_purpose.moving                52.18974685668945      0.003184679679427283   0.0012631876244127006
# loan_purpose.vacation              42.71484375            0.0026065099582505513  0.001033859431276514
# loan_purpose.educational_expenses  42.03619384765625      0.0025650979437532554  0.0010174335581964336
# loan_purpose.wedding               30.814329147338867     0.0018803265733436981  0.0007458223420853569
# loan_purpose.renewable_energy      6.0398030281066895     0.0003685558779231616  0.00014618588704683134
# [27 rows x 4 columns]
#
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.
